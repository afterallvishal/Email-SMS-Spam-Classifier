# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Loading and Representation

# %%
import pandas as pd

df = pd.read_csv("spam.csv", encoding="latin-1")
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 2228  ham                     Those were my exact intentions        NaN
# 2889  ham  Shuhui has bought ron's present it's a swatch ...        NaN
# 1685  ham                Cramps stopped. Going back to sleep        NaN
# 564   ham  Fuck babe ... I miss you already, you know ? C...        NaN
# 3580  ham                                       Ard 4 lor...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 2228        NaN        NaN
# 2889        NaN        NaN
# 1685        NaN        NaN
# 564         NaN        NaN
# 3580        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
#data cleaning
#EDA
#text preprocessing
#Model Building

# %% [markdown]
# # Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
#drop last three columns

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.sample(5)
# Out:
#         v1                                                 v2
# 277    ham                     Awesome, I'll see you in a bit
# 1713  spam  Hard LIVE 121 chat just 60p/min. Choose your g...
# 1130   ham                          Howz pain?hope u r fine..
# 3705   ham  Reading gud habit.. Nan bari hudgi yorge patai...
# 850    ham  U reach orchard already? U wan 2 go buy ticket...

# %%
#renaming the column

# %%
df.rename(columns={'v1':'target','v2':'text'},inplace=True)
df.sample(5)
# Out:
#      target                                               text
# 2789    ham        When you are big..| God will bring success.
# 424     ham  Send this to ur friends and receive something ...
# 2322    ham                            Should I be stalking u?
# 5004    ham  Guess which pub im in? Im as happy as a pig in...
# 4685    ham                  But pls dont play in others life.

# %%
#applying label encoder

# %%
from sklearn.preprocessing import LabelEncoder
encoder =LabelEncoder()

# %%
df['target']=encoder.fit_transform(df['target'])

# %%
df.head(5)
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
#check for duplicate values

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df=df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct='%0.2f')
plt.show()

# %%
#data is imbalanced

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in C:\Users\Vishal Shekhar\anaconda3\envs\ml_env\Lib\site-packages (3.10.0)
# Requirement already satisfied: defusedxml in C:\Users\Vishal Shekhar\anaconda3\envs\ml_env\Lib\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in C:\Users\Vishal Shekhar\anaconda3\envs\ml_env\Lib\site-packages (from nltk) (8.4.2)
# Requirement already satisfied: joblib in C:\Users\Vishal Shekhar\anaconda3\envs\ml_env\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\Vishal Shekhar\anaconda3\envs\ml_env\Lib\site-packages (from nltk) (2026.7.10)
# Requirement already satisfied: tqdm in C:\Users\Vishal Shekhar\anaconda3\envs\ml_env\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\Vishal Shekhar\anaconda3\envs\ml_env\Lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Vishal
# [nltk_data]     Shekhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Vishal
# [nltk_data]     Shekhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df['num_characters']=df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
#num of words

# %%
df['num_words']=df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df['num_sentences']=df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.455794       1.965564
# std         58.236293    13.324758       1.448541
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
#ham
df[df['target']==0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
#spam
df[df['target']==1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target']==0]['num_characters'])
sns.histplot(df[df['target']==1]['num_characters'],color='red')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target']==0]['num_words'])
sns.histplot(df[df['target']==1]['num_words'],color='red')
plt.show()

# %%
sns.pairplot(df,hue='target')
plt.show()

# %%
corr = df[['target','num_characters','num_words','num_sentences']].corr()

plt.figure(figsize=(6,4))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.show()

# %% [markdown]
# # Data Preprocessing
# #### Lowercase
# #### Tokenization
# #### Removing Special Characters
# #### Removing Stop Words and Punctuation
# #### Stemming

# %%
def transform_text(text):
    text=text.lower()
    text=nltk.word_tokenize(text)
    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
            
            
    return y

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string
import nltk

ps = PorterStemmer()
stop_words = set(stopwords.words('english'))   

def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)

    y = []
    for i in text:
        if i.isalnum():
            y.append(i)

    text = y[:]
    y.clear()

    for i in text:
        if i not in stop_words:
            y.append(i)

    text = y[:]
    y.clear()

    for i in text:
        y.append(ps.stem(i))

    return " ".join(y)

# %%
transform_text('I loved the YT lectures on ML .How about you ??')
# Out:
# 'love yt lectur ml'

# %%
df['text'][0]
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
df['transformed_text']=df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
from wordcloud import WordCloud
wc= WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_wc=wc.generate(df[df['target']==1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,7))
plt.imshow(spam_wc)

# %%
ham_wc=wc.generate(df[df['target']==0]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,7))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
spam_corpus=[]
for msg in df[df['target']==1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter

# %%
sns.barplot(
    data=pd.DataFrame(Counter(spam_corpus).most_common(30)),
    x=0,
    y=1
)

plt.xticks(rotation='vertical')
plt.show()

# %%
ham_corpus=[]
for msg in df[df['target']==0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35404

# %%
sns.barplot(
    data=pd.DataFrame(Counter(ham_corpus).most_common(30)),
    x=0,
    y=1
)

plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # Model Building

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

cv=CountVectorizer()
tfidf=TfidfVectorizer(max_features=3000)

# %%
X=tfidf.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y=df['target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred1=gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8694390715667312
# [[788 108]
#  [ 27 111]]
# 0.5068493150684932

# %%
mnb.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred2=mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(X_train,y_train)
# Out:
# BernoulliNB()

# %%
y_pred3=bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
#using the mnb due to it'ts high precision score

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel='sigmoid',gamma=1.0)
mnb = MultinomialNB()
lrc = LogisticRegression(solver='liblinear',penalty='l1')
rfc = RandomForestClassifier(n_estimators=50,random_state=2)
etc = ExtraTreesClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
svc = SVC(
    kernel='linear',    
    C=1.0
)

mnb = MultinomialNB()

lrc = LogisticRegression(
    solver='liblinear',
    penalty='l1',
    max_iter=1000,
    random_state=2
)

rfc = RandomForestClassifier(
    n_estimators=30,     
    random_state=2,
    n_jobs=-1
)

etc = ExtraTreesClassifier(
    n_estimators=30,      
    random_state=2,
    n_jobs=-1
)

xgb = XGBClassifier(
    n_estimators=30,
    max_depth=4,
    learning_rate=0.1,
    random_state=2,
    n_jobs=-1,
    verbosity=0,
    use_label_encoder=False
)

# %%
clfs={
    'SVC':svc,
    'NB':mnb,
    'LR':lrc,
    'RF':rfc,
    'ETC':etc,
    'xgb':xgb
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_test)
    accuracy=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)

    return accuracy, precision

# %%
train_classifier(svc,X_train,y_train,X_test,y_test)
# Out:
# (0.9787234042553191, 0.9754098360655737)

# %%
accuracy_scores=[]
precision_scores=[]
import time

for name, clf in clfs.items():
    print(f"\nStarting {name}...")
    start = time.time()

    current_accuracy, current_precision = train_classifier(
        clf, X_train, y_train, X_test, y_test
    )

    end = time.time()

    print(f"{name} completed in {end-start:.2f} sec")
    print("Accuracy:", current_accuracy)
    print("Precision:", current_precision)

    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# Starting SVC...
# SVC completed in 10.78 sec
# Accuracy: 0.9787234042553191
# Precision: 0.9754098360655737
#
# Starting NB...
# NB completed in 0.05 sec
# Accuracy: 0.9709864603481625
# Precision: 1.0
#
# Starting LR...
# LR completed in 0.12 sec
# Accuracy: 0.9584139264990329
# Precision: 0.9702970297029703
#
# Starting RF...
# C:\Users\Vishal Shekhar\anaconda3\envs\ml_env\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# C:\Users\Vishal Shekhar\anaconda3\envs\ml_env\Lib\site-packages\sklearn\linear_model\_logistic.py:1160: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# RF completed in 1.18 sec
# Accuracy: 0.971953578336557
# Precision: 0.9823008849557522
#
# Starting ETC...
# ETC completed in 3.17 sec
# Accuracy: 0.9758220502901354
# Precision: 0.9747899159663865
#
# Starting xgb...
# xgb completed in 0.95 sec
# Accuracy: 0.9381044487427466
# Precision: 0.9111111111111111

# %%
performance_df=pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision': precision_scores}).sort_values("Precision",ascending=False)

# %%
performance_df
# Out:
#   Algorithm  Accuracy  Precision
# 1        NB  0.959381   1.000000
# 3        RF  0.970019   1.000000
# 0       SVC  0.978723   0.975410
# 4       ETC  0.970986   0.973684
# 2        LR  0.951644   0.940000
# 5       xgb  0.941006   0.881188

# %%
performance_df1=pd.melt(performance_df,id_vars='Algorithm')

# %%
performance_df1
# Out:
#    Algorithm   variable     value
# 0         NB   Accuracy  0.959381
# 1         RF   Accuracy  0.970019
# 2        SVC   Accuracy  0.978723
# 3        ETC   Accuracy  0.970986
# 4         LR   Accuracy  0.951644
# 5        xgb   Accuracy  0.941006
# 6         NB  Precision  1.000000
# 7         RF  Precision  1.000000
# 8        SVC  Precision  0.975410
# 9        ETC  Precision  0.973684
# 10        LR  Precision  0.940000
# 11       xgb  Precision  0.881188

# %%
sns.catplot(x="Algorithm",y="value",hue='variable',data=performance_df1,kind='bar',height=5)
plt.ylim(0.5,1.0)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # Model Optimization

# %%
performance_df = pd.DataFrame({
    'Algorithm': list(clfs.keys()),
    'Accuracy': accuracy_scores,
    'Precision': precision_scores
}).sort_values('Precision', ascending=False)

performance_df
# Out:
#   Algorithm  Accuracy  Precision
# 1        NB  0.959381   1.000000
# 3        RF  0.970019   1.000000
# 0       SVC  0.978723   0.975410
# 4       ETC  0.970986   0.973684
# 2        LR  0.951644   0.940000
# 5       xgb  0.941006   0.881188

# %%
temp_df = pd.DataFrame({
    'Algorithm': list(clfs.keys()),
    'Accuracy_max_ft_3000': accuracy_scores,
    'Precision_max_ft_3000': precision_scores
}).sort_values('Precision_max_ft_3000', ascending=False)

temp_df
# Out:
#   Algorithm  Accuracy_max_ft_3000  Precision_max_ft_3000
# 1        NB              0.970986               1.000000
# 3        RF              0.971954               0.982301
# 0       SVC              0.978723               0.975410
# 4       ETC              0.975822               0.974790
# 2        LR              0.958414               0.970297
# 5       xgb              0.938104               0.911111

# %%
new_df=performance_df.merge(temp_df,on='Algorithm')
new_df
# Out:
#   Algorithm  Accuracy  Precision  Accuracy_max_ft_3000  Precision_max_ft_3000
# 0        NB  0.959381   1.000000              0.970986               1.000000
# 1        RF  0.970019   1.000000              0.971954               0.982301
# 2       SVC  0.978723   0.975410              0.978723               0.975410
# 3       ETC  0.970986   0.973684              0.975822               0.974790
# 4        LR  0.951644   0.940000              0.958414               0.970297
# 5       xgb  0.941006   0.881188              0.938104               0.911111

# %%
#voting classifier

# %%
svc = SVC(
    kernel='sigmoid',
    gamma='scale',     
    probability=True
)

etc = ExtraTreesClassifier(
    n_estimators=30,  
    random_state=2,
    n_jobs=-1
)

mnb = MultinomialNB()

# %%
from sklearn.ensemble import VotingClassifier

# %%
voting = VotingClassifier(estimators=[  ('svc', svc),('mnb', mnb), ('etc', etc)],voting='soft', n_jobs=-1)

# %%
voting.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('svc', SVC(kernel='sigmoid', probability=True)),
#                              ('mnb', MultinomialNB()),
#                              ('etc',
#                               ExtraTreesClassifier(n_estimators=30, n_jobs=-1,
#                                                    random_state=2))],
#                  n_jobs=-1, voting='soft')

# %%
y_pred=voting.predict(X_test)
print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
# Out:
# Accuracy : 0.9816247582205029
# Precision: 0.9917355371900827

# %%
#applying stacking

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression

# %%
estimators = [
    ('svm', svc),
    ('nb', mnb),
    ('et', etc)
]

# %%
clf = StackingClassifier(estimators=estimators, 
    final_estimator=LogisticRegression(max_iter=1000),
    cv=3,          
    n_jobs=-1)

clf.fit(X_train, y_train)
# Out:
# StackingClassifier(cv=3,
#                    estimators=[('svm', SVC(kernel='sigmoid', probability=True)),
#                                ('nb', MultinomialNB()),
#                                ('et',
#                                 ExtraTreesClassifier(n_estimators=30, n_jobs=-1,
#                                                      random_state=2))],
#                    final_estimator=LogisticRegression(max_iter=1000),
#                    n_jobs=-1)

# %%
y_pred=clf.predict(X_test)
print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
# Out:
# Accuracy : 0.9787234042553191
# Precision: 0.953125

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))

# %%
import os

os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'model.pkl',
#  'spam.csv',
#  'spam_classifier.ipynb',
#  'vectorizer.pkl']
